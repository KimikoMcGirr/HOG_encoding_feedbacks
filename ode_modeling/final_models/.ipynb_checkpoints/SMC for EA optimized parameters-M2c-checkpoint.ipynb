# %% [markdown]
# # Import packages and set settings

# %%
# %load_ext autoreload
# %autoreload 2

import sys
# sys.path.insert(1, './python_mods/')
sys.path.insert(1, '../../python_modules')
import plotting
import model_supp 
import model
import saving

# %%
# %matplotlib inline
import pathlib
import seaborn as sns
import matplotlib.pyplot as plt
import pickle
import numpy as np
import pandas as pd
import os
import collections

# %%
# plt.style.use("seaborn-whitegrid")
plt.rcParams['figure.figsize'] = [10.0, 8.0]
plt.rcParams['axes.titlesize'] = 20
plt.rcParams['axes.labelsize'] = 18
plt.rcParams['xtick.labelsize'] = 14
plt.rcParams['ytick.labelsize'] = 14
plt.rcParams['grid.linestyle'] = '-'
plt.rcParams['legend.fontsize'] = 14
colors = [i['color'] for i in plt.rcParams['axes.prop_cycle']]

# %% [markdown]
# # Functions

# %%
def recalc_mses(model_fxns, EA_theta_set, exp_data, exp_time, params_constants, initials, ptpD=False):
    mses = []
    for params in EA_theta_set:
        mses.append(sum(model_supp.calc_sim_score(model_fxns, params, exp_data, exp_time, params_constants, initials, ptpD=False)[:18]))
    re_idx = sorted(range(len(mses)), key=lambda k: mses[k])
    thetas = EA_theta_set[re_idx]
    mses = np.sort(mses)
    return mses, thetas

def sort_mses_thetas(mses, thetas):
    re_idx = sorted(range(len(mses)), key=lambda k: mses[k])
    thetas = thetas[re_idx]
    return np.sort(mses), thetas

def calc_mse(model_fxns, theta, exp_data, exp_time, params_constants, initials, ptpD=False):
    # Takes 
    return sum(model_supp.calc_sim_score(model_fxns, theta, exp_data, exp_time, params_constants, initials, ptpD)[:18]) ##AMY (insert your own error function)

def def_schedules(sorted_mses):
    best_mse = sorted_mses[0]
    worst_mse = sorted_mses[-1]
    
#     e1 = (best_mse+worst_mse)/2 #will take longer to run
    e1 = worst_mse
    e2 = (e1+best_mse)/2
    e3 = (e2+best_mse)/2
    e4 = (e3+best_mse)/2
#     e5 = (e4+best_mse)/2
    return e1, e2, e3, e4
    
def scaled_prob_mses(mses, top=.99, bot=.01):
    # mses is SORTED 
    scale = [(top-bot)*(x-mses[0])/(mses[-1]-mses[0])+bot for x in mses]
    inv = [1/x for x in scale]
    probs = [x/sum(inv) for x in inv]
    return probs

def draw_thetas(sorted_params, probs):
    idx = np.random.choice(range(len(sorted_params)), 1, p=probs)
    return sorted_params[idx][0]

def step_theta(theta):
    log_theta = np.log10(theta) 
    theta_prime = np.concatenate([10**(np.random.uniform(x-.1,x+.1,1)) for x in log_theta], axis=0)
    return theta_prime

def run_schedule(prior_thetas, probs, ei, num_theta_primes):
    thetas_ei = []
    mses_ei = []
    c = collections.Counter({'Pass': 0, 'Fail': 0}) 
    while len(thetas_ei) < num_theta_primes:
        theta = draw_thetas(prior_thetas, probs)
        theta_prime = step_theta(theta)
        mse = calc_mse(M2c_fxns, theta_prime, exp_data, exp_time, params_constants, initials, ptpD=False) ##AMY error fxn
        if mse < ei:
            c['Pass'] += 1
            thetas_ei.append(theta_prime)
            mses_ei.append(mse)
            if len(mses_ei) % int(num_theta_primes*.1) == 0:
                print(str(int(len(mses_ei)/num_theta_primes*100)) + "% complete.") 
        else:
            c['Fail'] += 1
    return np.asarray(mses_ei), np.asarray(thetas_ei), c

# %% [markdown]
# # Model

# %% [markdown]
# ## Model Functions

# %%
from scipy.optimize import fsolve
from scipy.integrate import odeint

# %%
# def simulate_t100a_experiment_M2b_kb(m, inits, total_protein, sig, learned_params, time,  run_type=None):
#         beta_3, alpha, kb, k1, k3, k5, s7, k2, k4, k6, d8, K_1, K_3, K_5, K_2, K_4, K_6 = learned_params #17
#         learned_params = beta_3, 0, kb, k1, k3, k5, 0, k2, k4, k6, d8, K_1, K_3, K_5, K_2, K_4, K_6
#         #solve odes:
#         odes = odeint(m, inits, time, args=(total_protein, sig, learned_params, run_type))
#         return odes

# def simulate_nopos_experiment_M2b_kb(m, inits, total_protein, sig, learned_params, time,  run_type=None):
#     beta_3, alpha, kb, k1, k3, k5, s7, k2, k4, k6, d8, K_1, K_3, K_5, K_2, K_4, K_6 = learned_params #17
#     learned_params = beta_3, 0, kb, k1, k3, k5, s7, k2, k4, k6, d8, K_1, K_3, K_5, K_2, K_4, K_6
#     #solve odes:
#     odes = odeint(m, inits, time, args=(total_protein, sig, learned_params, run_type))
#     return odes

# def M2b_kb(initials,t,total_protein,sig,params, run_type=None):
# #     if run_type:
# #         if run_type[0] == 'ramp':
# #             sig = signal_ramp_special(t)
# #         elif run_type[0] == 'rand':
# #             sig = get_ramp_signal(t, run_type[1])
# #         elif run_type[0] == 'man':
# #             sig = get_manual_signal(t)

#     MAP3K, MAP2K, MAPK, gly = initials
#     MAP3K_t, MAP2K_t, MAPK_t, _ = total_protein
#     beta_3, alpha, kb, k1, k3, k5, s7, k2, k4, k6, d8, K_1, K_3, K_5, K_2, K_4, K_6 = params #17

#     MAP3K_I = MAP3K_t-MAP3K
#     MAP2K_I = MAP2K_t-MAP2K
#     MAPK_I = MAPK_t-MAPK
#     # PTP_I = PTP_t-PTP

#     dMAP3K = (((sig*k1 + kb)/(1+gly/beta_3))*MAP3K_I)/(K_1+MAP3K_I) - (k2*MAP3K/(K_2+MAP3K))
#     dMAP2K = (((k3*MAP3K + MAPK*alpha)*MAP2K_I)/(K_3+MAP2K_I)) - (k4*MAP2K/(K_4+MAP2K)) #bug
#     dMAPK = (((k5)*MAP2K)*MAPK_I)/(K_5+MAPK_I) - (k6*MAPK)/(K_6+MAPK)
#     dgly = s7*MAPK - d8*gly

#     return dMAP3K, dMAP2K, dMAPK, dgly

# def run_ss(m, inits, total_protein, learned_params):
#     ss = fsolve(m, inits, args=(0,total_protein, 0, learned_params))
#     return ss

# def simulate_wt_experiment(m, inits, total_protein, sig, learned_params, time, run_type=None):
#     odes = odeint(m, inits, time, args=(total_protein, sig, learned_params, run_type))
#     return odes

# def molarity_conversion(molecules):
#     Na = 6.02214076*10**23
#     cell_volume = 44                                                                 # approx volume of a SC yeast cell
#     return molecules/(Na*cell_volume*10**-15)*1000000 

# class Model():
#     def __init__(self, m, t100a, nopos=None):
#         self.m = m
#         self.t100a = t100a
#         self.nopos = nopos

# %% [markdown]
# ## Model Variables (Constants)

# %%
dt = 0.1
steps = 601
time = np.linspace(0,dt*steps,steps)


MAP3K_t = model_supp.molarity_conversion(701)
MAP2K_t = model_supp.molarity_conversion(2282)
MAPK_t = model_supp.molarity_conversion(5984)
PTP_t = model_supp.molarity_conversion(118+400)

MAP3K = 0.05*MAP3K_t # estimated (so not 0)
MAP2K = 0.05975380333*MAP2K_t # from the biological data
MAPK = 0.00540042381*MAPK_t  # from the biological data
gly = 0.00001 # placeholder (so not 0)
PTP = model_supp.molarity_conversion(118+400) # start with all on


labelnames = ['$- fb$', '$+ fb$', '$kb$',
              '$k_1$', '$k_3$', '$k_5$', '$s_1$',
              '$k_2$', '$k_4$', '$k_6$', '$d_1$',
              '$K_{M1}$', '$K_{M3}$', '$K_{M5}$',
              '$K_{M2}$', '$K_{M4}$', '$K_{M6}$']


minimums = [-4, -4, -4,
        -4, -4, -4, -4,
        -4, -4, -4, -4, 
        -4, -4, -4, 
        -4, -4, -4]

maximums = [ 4, 4, 4, 
        4, 4, 4, 4,
        4, 4, 4, 4, 
        4, 4, 4,
        4, 4, 4]

diff = np.asarray(maximums)-np.asarray(minimums) #for plotting
dims = (diff, minimums) #for plotting

initials = [MAP3K, MAP2K, MAPK, gly]

params_constants = [MAP3K_t, MAP2K_t, MAPK_t, 1] 

doses = [0, 50000, 150000, 250000, 350000, 450000, 550000]

# %% [markdown]
# # Load experimental data

# %%
exp_data, exp_time = model_supp.get_data()

mapk_wt_data, mapk_t100a_data, map2k_wt_data, map2k_t100a_data, hog1_ramp_data, mapk_ptpD_data = exp_data
mapk_time, mapk_time_t100a_long, mapk_ramp_time = exp_time 

mapk_data_t100a_long = [mapk_t100a_data[0]] 

mapk_t100a_data = [mapk_t100a_data[0][:9]] + mapk_t100a_data[1:] #shorten for plotting

# %% [markdown]
# # Load simulation data

# %%
folder = 'C:/Users/sksuzuki/Desktop/killdevil/runs_for_paper/191205_kb_M2c/'

all_params, last_params, all_mses, last_mses = model_supp.get_sim_data(folder, num_sims=2000)
# Out:
# -----------------------------------------------------
# KeyboardInterrupt   Traceback (most recent call last)
# <ipython-input-144-67cf7348727f> in <module>()
#       1 folder = 'C:/Users/sksuzuki/Desktop/killdevil/runs_for_paper/191205_kb_M2c/'
#       2
# ----> 3 all_params, last_params, all_mses, last_mses = model_supp.get_sim_data(folder, num_sims=2000)
#       4
#       5 M2c_fxns = model.Model(model.M2c_kb, model.simulate_t100a_experiment_M2a_kb, model.simulate_nopos_experiment_M2a_kb, model.M2c_kb_on_off)
#
# ~\Documents\GitHub\HOG_encoding_feedbacks\python_modules\model_supp.py in get_sim_data(folder, num_sims)
#      57                     break
#      58             if os.path.getsize(loaded_data) > 0:
# ---> 59                 with open(loaded_data, 'rb') as f:
#      60                     new_data = pickle.load(f)
#      61                     all_mses.append(np.asarray(new_data[0]))
#
# KeyboardInterrupt:

# %%
M2c_fxns = model.Model(model.M2c_kb, model.simulate_t100a_experiment_M2a_kb, model.simulate_nopos_experiment_M2a_kb, model.M2c_kb_on_off)

# %%
## sort
M2c_sorted_mses_EA, M2c_sorted_thetas_EA = sort_mses_thetas(last_mses, last_params)

# %% [markdown]
# # Check EA results

# %%
plotting.plt_idx_vs_mse(M2c_sorted_mses_EA, len(M2c_sorted_mses_EA))
# Out:
# No handles with labels found to put in legend.

# %%
plotting.plt_idx_vs_mse(M2c_sorted_mses_EA, 100)
# Out:
# No handles with labels found to put in legend.

# %%
# original parameter values
plotting.plt_param_behaviors(M2c_fxns, M2c_sorted_thetas_EA, 20, params_constants, initials,  doses, time, 2, mapk_wt_data, mapk_t100a_data, mapk_time,ss=True)
# Out:
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\scipy\optimize\minpack.py:163: RuntimeWarning: The number of calls to function has reached maxfev = 1000.
#   warnings.warn(msg, RuntimeWarning)
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\scipy\optimize\minpack.py:163: RuntimeWarning: The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
#   warnings.warn(msg, RuntimeWarning)
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\scipy\optimize\minpack.py:163: RuntimeWarning: The iteration is not making good progress, as measured by the
#   improvement from the last five Jacobian evaluations.
#   warnings.warn(msg, RuntimeWarning)

# %%
plotting.plt_param_behaviors(M2c_fxns, M2c_sorted_thetas_EA, 10, params_constants, initials,  [150000,550000], time, 1, map2k_wt_data, map2k_t100a_data, mapk_time,ss=True)
# Out:
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\scipy\optimize\minpack.py:163: RuntimeWarning: The number of calls to function has reached maxfev = 1000.
#   warnings.warn(msg, RuntimeWarning)
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\scipy\optimize\minpack.py:163: RuntimeWarning: The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
#   warnings.warn(msg, RuntimeWarning)

# %%
mapk_time_t100a_long = [0, 2, 5, 10, 15, 20, 25, 30, 60, 90, 120, 150, 180, 240, 300]

plotting.plt_t100a_long(M2c_fxns, M2c_sorted_thetas_EA, 10, params_constants, initials, mapk_data_t100a_long[0], mapk_time_t100a_long)
# Out:
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\scipy\optimize\minpack.py:163: RuntimeWarning: The number of calls to function has reached maxfev = 1000.
#   warnings.warn(msg, RuntimeWarning)
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\scipy\optimize\minpack.py:163: RuntimeWarning: The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
#   warnings.warn(msg, RuntimeWarning)

# %%
plotting.plt_ramp_behaviors(M2c_fxns, M2c_sorted_thetas_EA, 50, params_constants, initials, time, 2, ss = True, hog1_ramp_data=hog1_ramp_data, mapk_ramp_time=mapk_ramp_time)
# Out:
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\scipy\optimize\minpack.py:163: RuntimeWarning: The number of calls to function has reached maxfev = 1000.
#   warnings.warn(msg, RuntimeWarning)
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\scipy\optimize\minpack.py:163: RuntimeWarning: The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
#   warnings.warn(msg, RuntimeWarning)
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\scipy\optimize\minpack.py:163: RuntimeWarning: The iteration is not making good progress, as measured by the
#   improvement from the last five Jacobian evaluations.
#   warnings.warn(msg, RuntimeWarning)

# %%
df_top_thetas_EA = pd.DataFrame(M2c_sorted_thetas_EA)
df_top_thetas_EA.columns = labelnames

num_plt = 200
df_plt = pd.DataFrame(M2c_sorted_thetas_EA[:num_plt])
df_plt.columns = labelnames
df_plt_log = df_plt.apply(np.log10)
df_plt_log_M = df_plt_log.melt(var_name='param', value_name='vals')
plotting.plt_param_ranges(labelnames, 'M2a', dims, df_plt_log_M, single_theta=df_plt_log, num=0) #black dot is best param

# %%
sns.distplot(np.log10(df_top_thetas_EA[labelnames[6]]))

# %%
sims_M2c_kb_ea_l = plotting.simdata_to_list(M2c_fxns, M2c_sorted_thetas_EA, params_constants, initials, time, 2, ss = True)
# Out:
# 0% complete.
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\scipy\optimize\minpack.py:163: RuntimeWarning: The number of calls to function has reached maxfev = 1000.
#   warnings.warn(msg, RuntimeWarning)
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\scipy\optimize\minpack.py:163: RuntimeWarning: The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
#   warnings.warn(msg, RuntimeWarning)
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\scipy\optimize\minpack.py:163: RuntimeWarning: The iteration is not making good progress, as measured by the
#   improvement from the last five Jacobian evaluations.
#   warnings.warn(msg, RuntimeWarning)
# 9% complete.
# 19% complete.
# 29% complete.
# 39% complete.
# 49% complete.
# 59% complete.
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\scipy\integrate\odepack.py:236: ODEintWarning: Excess work done on this call (perhaps wrong Dfun type). Run with full_output = 1 to get quantitative information.
#   warnings.warn(warning_msg, ODEintWarning)
# 69% complete.
# 79% complete.
# 89% complete.
# 99% complete.

# %%
plotting.plt_ramp_cis(sims_M2c_kb_ea_l, time, hog1_ramp_data=hog1_ramp_data, mapk_ramp_time=mapk_ramp_time)
# Out:
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\seaborn\timeseries.py:183: UserWarning: The `tsplot` function is deprecated and will be removed in a future release. Please update your code to use the new `lineplot` function.
#   warnings.warn(msg, UserWarning)

# %%
plotting.plt_ramp_cis(sims_M2c_kb_ea_l, time, hog1_ramp_data=hog1_ramp_data, mapk_ramp_time=mapk_ramp_time, ci='sd')
# Out:
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\seaborn\timeseries.py:183: UserWarning: The `tsplot` function is deprecated and will be removed in a future release. Please update your code to use the new `lineplot` function.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# # SMC

# %% [markdown]
# ## Try different sizes of EA
#
# I've been using top 500 and it's worked really well, but here I'm using top 20 so that it runs fast

# %%
M2c_new_mses_EA, M2c_new_thetas_EA = recalc_mses(M2c_fxns, M2c_sorted_thetas_EA, exp_data, exp_time, params_constants, initials)

print(M2c_new_mses_EA[:10])
# Out:
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\scipy\optimize\minpack.py:163: RuntimeWarning: The number of calls to function has reached maxfev = 1000.
#   warnings.warn(msg, RuntimeWarning)
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\scipy\optimize\minpack.py:163: RuntimeWarning: The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
#   warnings.warn(msg, RuntimeWarning)
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\scipy\optimize\minpack.py:163: RuntimeWarning: The iteration is not making good progress, as measured by the
#   improvement from the last five Jacobian evaluations.
#   warnings.warn(msg, RuntimeWarning)
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\scipy\integrate\odepack.py:236: ODEintWarning: Repeated convergence failures (perhaps bad Jacobian or tolerances). Run with full_output = 1 to get quantitative information.
#   warnings.warn(warning_msg, ODEintWarning)
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\scipy\integrate\odepack.py:236: ODEintWarning: Excess work done on this call (perhaps wrong Dfun type). Run with full_output = 1 to get quantitative information.
#   warnings.warn(warning_msg, ODEintWarning)
# [1478.14306102 1626.54296106 1690.73008812 1709.54099597 1710.78560993
#  1721.51422677 1723.47044062 1758.1880056  1776.88057954 1781.96083847]

# %%
plotting.plt_idx_vs_mse(M2c_new_mses_EA, len(M2c_new_mses_EA))
# Out:
# No handles with labels found to put in legend.

# %%
M2c_EA_thetas_1perc = M2c_new_thetas_EA[:500]
M2c_EA_mses_1perc = M2c_new_mses_EA[:500]

# %% [markdown]
# ## Define schedules

# %% [markdown]
# I've been messing around with where I start with the schedule and how many schedules to run

# %%
e1, e2, e3, e4 = def_schedules(M2c_EA_mses_1perc)

print("Best MSE: " + str(M2c_EA_mses_1perc[0]))
print("Worst MSE: " + str(M2c_EA_mses_1perc[-1]))
print()
print("Schedules: " + str(e1),str(e2),str(e3),str(e4))
print()
# Out:
# Best MSE: 1478.1430610228672
# Worst MSE: 3207.2168047024957
#
# Schedules: 3207.2168047024957 2342.679932862681 1910.4114969427742 1694.2772789828207

# %% [markdown]
# ## Define probability

# %% [markdown]
# I've also been messing around with the `top` and `bot` params of `scaled_prob_mses`.
# - (.9 and .1)
# - (.95 and .05)
# - (.99 and .01)
#
# I've noticed that with the larger number of EA thetas, the more extreme ranges are better.
# If you start with a small number of EA thetas, being more conservative with the ranges
# results in more balanced probabilities.

# %%
probs = scaled_prob_mses(M2c_EA_mses_1perc, top=.99, bot=.01) 

print(probs[:5]) 
print(probs[-5:])
# Out:
# [0.09767809043614335, 0.010379171703028246, 0.007485511578676806, 0.006920106843853533, 0.006885694786716077]
# [0.0009890730474965252, 0.0009880851088015414, 0.0009870400241783542, 0.0009866570659343027, 0.0009866473781428623]

# %% [markdown]
# ## Schedule 1

# %% [markdown]
# I use `num_theta_primes = 1000`, but set to 100 to be faster.

# %%
mses_e1, thetas_e1, count_e1 = run_schedule(M2c_EA_thetas_1perc, probs, e1, num_theta_primes=1000)
mses_e1_sort, thetas_e1_sort = sort_mses_thetas(mses_e1, thetas_e1)
# Out:
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\scipy\optimize\minpack.py:163: RuntimeWarning: The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
#   warnings.warn(msg, RuntimeWarning)
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\scipy\integrate\odepack.py:236: ODEintWarning: Repeated convergence failures (perhaps bad Jacobian or tolerances). Run with full_output = 1 to get quantitative information.
#   warnings.warn(warning_msg, ODEintWarning)
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\scipy\integrate\odepack.py:236: ODEintWarning: Excess work done on this call (perhaps wrong Dfun type). Run with full_output = 1 to get quantitative information.
#   warnings.warn(warning_msg, ODEintWarning)
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\scipy\optimize\minpack.py:163: RuntimeWarning: The iteration is not making good progress, as measured by the
#   improvement from the last five Jacobian evaluations.
#   warnings.warn(msg, RuntimeWarning)
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\scipy\optimize\minpack.py:163: RuntimeWarning: The number of calls to function has reached maxfev = 1000.
#   warnings.warn(msg, RuntimeWarning)
# ../../python_modules\model.py:360: RuntimeWarning: overflow encountered in double_scalars
#   dMAPK = (((k5*MAP2K + MAPK*alpha))*MAPK_I)/(K_5+MAPK_I) - (k6*MAPK)/(K_6+MAPK)  #bug
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\scipy\integrate\odepack.py:236: ODEintWarning: Illegal input detected (internal error). Run with full_output = 1 to get quantitative information.
#   warnings.warn(warning_msg, ODEintWarning)
# ../../python_modules\model.py:358: RuntimeWarning: divide by zero encountered in double_scalars
#   dMAP3K = (((sig*k1 + kb)/(1+gly/beta_3))*MAP3K_I)/(K_1+MAP3K_I) - (k2*MAP3K/(K_2+MAP3K))
# ../../python_modules\model.py:358: RuntimeWarning: invalid value encountered in double_scalars
#   dMAP3K = (((sig*k1 + kb)/(1+gly/beta_3))*MAP3K_I)/(K_1+MAP3K_I) - (k2*MAP3K/(K_2+MAP3K))
# ../../python_modules\model.py:359: RuntimeWarning: invalid value encountered in double_scalars
#   dMAP2K = (((k3)*MAP3K*MAP2K_I)/(K_3+MAP2K_I)) - (k4*MAP2K/(K_4+MAP2K))
# ../../python_modules\model.py:360: RuntimeWarning: invalid value encountered in double_scalars
#   dMAPK = (((k5*MAP2K + MAPK*alpha))*MAPK_I)/(K_5+MAPK_I) - (k6*MAPK)/(K_6+MAPK)  #bug
# 10% complete.
# 20% complete.
# 30% complete.
# 40% complete.
# ../../python_modules\model_supp.py:162: RuntimeWarning: overflow encountered in square
#   mapk = odes[:,2]/total_protein[2]*100
# 50% complete.
# ../../python_modules\model_supp.py:205: RuntimeWarning: overflow encountered in square
#   mapk = odes[:,2]/total_protein[2]*100
# 60% complete.
# 70% complete.
# 80% complete.
# 90% complete.
# 100% complete.

# %%
df_top_thetas_e1 = pd.DataFrame(thetas_e1_sort)
df_top_thetas_e1.columns = labelnames

df_top_thetas_e1.to_csv('M2c_kb_thetas_e1.csv')

# %%
num_plt = 100
df_plt = pd.DataFrame(thetas_e1_sort[:num_plt])
df_plt.columns = labelnames
df_plt_log = df_plt.apply(np.log10)
df_plt_log_M = df_plt_log.melt(var_name='param', value_name='vals')

plotting.plt_param_ranges(labelnames, 'M2a', dims, df_plt_log_M, single_theta=df_plt_log, num=0)

# %%
sns.distplot(np.log10(df_top_thetas_e1[labelnames[6]]))

# %%
plotting.plt_param_behaviors(M2c_fxns, thetas_e1_sort, 20, params_constants, initials,  doses, time, 2, mapk_wt_data, mapk_t100a_data, mapk_time,ss=True)

# %%
plotting.plt_param_behaviors(M2c_fxns, thetas_e1_sort, 20, params_constants, initials,  [150000, 550000], time, 1, map2k_wt_data, map2k_t100a_data, mapk_time,ss=True)

# %%
sims_M2b_kb_e1 = plotting.simdata_to_df(M2b_fxns, thetas_e1_sort, params_constants, initials, time, 2, ss = True)

# %%
plotting.plt_ramp_cis(sims_M2b_kb_e1, hog1_ramp_data=hog1_ramp_data, mapk_ramp_time=mapk_ramp_time)

# %%
plotting.plt_ramp_cis(sims_M2b_kb_e1, hog1_ramp_data=hog1_ramp_data, mapk_ramp_time=mapk_ramp_time, ci='sd')

# %% [markdown]
# ## Schedule 2

# %% [markdown]
# Redefine probs based on results of last schedule.

# %%
probs = scaled_prob_mses(mses_e1_sort, top=.99, bot=.01) 

print(probs[:5]) 
print(probs[-5:])
# Out:
# [0.05134597412186181, 0.02929014402358853, 0.013623653325720866, 0.012073564390108649, 0.005970748534940234]
# [0.0005193215089429627, 0.0005191316522114336, 0.0005191147479554458, 0.0005186744736978851, 0.0005186462032511295]

# %%
mses_e2, thetas_e2, count_e2 = run_schedule(thetas_e1_sort, probs, e2, num_theta_primes=1000)
mses_e2_sort, thetas_e2_sort = sort_mses_thetas(mses_e2, thetas_e2)
# Out:
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\scipy\optimize\minpack.py:163: RuntimeWarning: The number of calls to function has reached maxfev = 1000.
#   warnings.warn(msg, RuntimeWarning)
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\scipy\optimize\minpack.py:163: RuntimeWarning: The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
#   warnings.warn(msg, RuntimeWarning)
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\scipy\integrate\odepack.py:236: ODEintWarning: Excess work done on this call (perhaps wrong Dfun type). Run with full_output = 1 to get quantitative information.
#   warnings.warn(warning_msg, ODEintWarning)
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\scipy\optimize\minpack.py:163: RuntimeWarning: The iteration is not making good progress, as measured by the
#   improvement from the last five Jacobian evaluations.
#   warnings.warn(msg, RuntimeWarning)
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\scipy\integrate\odepack.py:236: ODEintWarning: Repeated convergence failures (perhaps bad Jacobian or tolerances). Run with full_output = 1 to get quantitative information.
#   warnings.warn(warning_msg, ODEintWarning)
# ../../python_modules\model.py:360: RuntimeWarning: overflow encountered in double_scalars
#   dMAPK = (((k5*MAP2K + MAPK*alpha))*MAPK_I)/(K_5+MAPK_I) - (k6*MAPK)/(K_6+MAPK)  #bug
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\scipy\integrate\odepack.py:236: ODEintWarning: Illegal input detected (internal error). Run with full_output = 1 to get quantitative information.
#   warnings.warn(warning_msg, ODEintWarning)
# ../../python_modules\model_supp.py:162: RuntimeWarning: overflow encountered in square
#   mapk = odes[:,2]/total_protein[2]*100
# ../../python_modules\model.py:358: RuntimeWarning: invalid value encountered in double_scalars
#   dMAP3K = (((sig*k1 + kb)/(1+gly/beta_3))*MAP3K_I)/(K_1+MAP3K_I) - (k2*MAP3K/(K_2+MAP3K))
# ../../python_modules\model.py:359: RuntimeWarning: invalid value encountered in double_scalars
#   dMAP2K = (((k3)*MAP3K*MAP2K_I)/(K_3+MAP2K_I)) - (k4*MAP2K/(K_4+MAP2K))
# ../../python_modules\model.py:360: RuntimeWarning: invalid value encountered in double_scalars
#   dMAPK = (((k5*MAP2K + MAPK*alpha))*MAPK_I)/(K_5+MAPK_I) - (k6*MAPK)/(K_6+MAPK)  #bug
# 10% complete.
# 20% complete.
# ../../python_modules\model_supp.py:205: RuntimeWarning: overflow encountered in square
#   mapk = odes[:,2]/total_protein[2]*100
# 30% complete.
# 40% complete.
# 50% complete.
# ../../python_modules\model_supp.py:188: RuntimeWarning: overflow encountered in double_scalars
#   mses[i] = ((data - mapk[closest_idxs_mapk])**2).mean()
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: RuntimeWarning: overflow encountered in double_scalars
# ../../python_modules\model.py:358: RuntimeWarning: divide by zero encountered in double_scalars
#   dMAP3K = (((sig*k1 + kb)/(1+gly/beta_3))*MAP3K_I)/(K_1+MAP3K_I) - (k2*MAP3K/(K_2+MAP3K))
# ../../python_modules\model.py:361: RuntimeWarning: invalid value encountered in double_scalars
#   dgly = s7*MAPK - d8*gly
# 60% complete.
# 70% complete.
# 80% complete.
# 90% complete.
# 100% complete.

# %%
df_top_thetas_e2 = pd.DataFrame(thetas_e2_sort)
df_top_thetas_e2.columns = labelnames

df_top_thetas_e2.to_csv('M2c_kb_thetas_e2.csv')

# %%
num_plt = 200
df_plt = pd.DataFrame(thetas_e2_sort[:num_plt])
df_plt.columns = labelnames
df_plt_log = df_plt.apply(np.log10)
df_plt_log_M = df_plt_log.melt(var_name='param', value_name='vals')

plotting.plt_param_ranges(labelnames, 'M2a', dims, df_plt_log_M, single_theta=df_plt_log, num=0)

# %%
sns.distplot(np.log10(df_top_thetas_e2[labelnames[6]]))

# %%
plotting.plt_param_behaviors(M2c_fxns, thetas_e2_sort, 20, params_constants, initials,  doses, time, 2, mapk_wt_data, mapk_t100a_data, mapk_time,ss=True)

# %%
plotting.plt_param_behaviors(M2c_fxns, thetas_e2_sort, 20, params_constants, initials,  [150000, 550000], time, 1, map2k_wt_data, map2k_t100a_data, mapk_time,ss=True)

# %%
sims_M2b_kb_e2 = plotting.simdata_to_list(M2c_fxns, thetas_e2_sort, params_constants, initials, time, 2, ss = True)
# Out:
# 0% complete.
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\scipy\optimize\minpack.py:163: RuntimeWarning: The number of calls to function has reached maxfev = 1000.
#   warnings.warn(msg, RuntimeWarning)
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\scipy\optimize\minpack.py:163: RuntimeWarning: The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
#   warnings.warn(msg, RuntimeWarning)
# 10% complete.
# 20% complete.
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\scipy\optimize\minpack.py:163: RuntimeWarning: The iteration is not making good progress, as measured by the
#   improvement from the last five Jacobian evaluations.
#   warnings.warn(msg, RuntimeWarning)
# 30% complete.
# 40% complete.
# 50% complete.
# 60% complete.
# 70% complete.
# 80% complete.
# 90% complete.

# %%
plotting.plt_ramp_cis(sims_M2b_kb_e2, time, hog1_ramp_data=hog1_ramp_data, mapk_ramp_time=mapk_ramp_time)
# Out:
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\seaborn\timeseries.py:183: UserWarning: The `tsplot` function is deprecated and will be removed in a future release. Please update your code to use the new `lineplot` function.
#   warnings.warn(msg, UserWarning)

# %%
plotting.plt_ramp_cis(sims_M2b_kb_e2, time, hog1_ramp_data=hog1_ramp_data, mapk_ramp_time=mapk_ramp_time, ci='sd')
# Out:
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\seaborn\timeseries.py:183: UserWarning: The `tsplot` function is deprecated and will be removed in a future release. Please update your code to use the new `lineplot` function.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# ## Turning on and off inhib

# %%
thetas_e4_sort = np.array(pd.read_csv("M2c_kb_thetas_e4.csv").drop(['Unnamed: 0'], axis=1))

# %%
M2c_inhib_sims = plotting.inhibdata_to_list(M2c_fxns, thetas_e4_sort, params_constants, initials, time, 2, sig=450000, run_type=['ramp'], ss = True)
# Out:
# 0% complete.
# 10% complete.
# 20% complete.
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\scipy\optimize\minpack.py:163: RuntimeWarning: The iteration is not making good progress, as measured by the
#   improvement from the last five Jacobian evaluations.
#   warnings.warn(msg, RuntimeWarning)
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\scipy\optimize\minpack.py:163: RuntimeWarning: The number of calls to function has reached maxfev = 1000.
#   warnings.warn(msg, RuntimeWarning)
# 30% complete.
# 40% complete.
# 50% complete.
# 60% complete.
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\scipy\optimize\minpack.py:163: RuntimeWarning: The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
#   warnings.warn(msg, RuntimeWarning)
# 70% complete.
# 80% complete.
# 90% complete.

# %%
plotting.plt_inhib_cis(M2c_inhib_sims, time, ci="sd") #t 5
# Out:
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\seaborn\timeseries.py:183: UserWarning: The `tsplot` function is deprecated and will be removed in a future release. Please update your code to use the new `lineplot` function.
#   warnings.warn(msg, UserWarning)

# %%
plotting.plt_inhib_cis(M2c_inhib_sims, time, ci="sd") #t 5
# Out:
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\seaborn\timeseries.py:183: UserWarning: The `tsplot` function is deprecated and will be removed in a future release. Please update your code to use the new `lineplot` function.
#   warnings.warn(msg, UserWarning)

# %%
plotting.plt_inhib_cis(M2c_inhib_sims, time, ci="sd") # t 7.5
# Out:
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\seaborn\timeseries.py:183: UserWarning: The `tsplot` function is deprecated and will be removed in a future release. Please update your code to use the new `lineplot` function.
#   warnings.warn(msg, UserWarning)

# %%
plotting.plt_inhib_cis(M2c_inhib_sims, time, ci="sd") # t 10
# Out:
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\seaborn\timeseries.py:183: UserWarning: The `tsplot` function is deprecated and will be removed in a future release. Please update your code to use the new `lineplot` function.
#   warnings.warn(msg, UserWarning)

# %%
M2c_inhib_simsa = plotting.inhibdata_to_list(M2c_fxns, thetas_e4_sort, params_constants, initials, time, 2, sig=450000, run_type=['ramp'], ss = True)
# Out:
# 0% complete.
# 10% complete.
# 20% complete.
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\scipy\optimize\minpack.py:163: RuntimeWarning: The iteration is not making good progress, as measured by the
#   improvement from the last five Jacobian evaluations.
#   warnings.warn(msg, RuntimeWarning)
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\scipy\optimize\minpack.py:163: RuntimeWarning: The number of calls to function has reached maxfev = 1000.
#   warnings.warn(msg, RuntimeWarning)
# 30% complete.
# 40% complete.
# 50% complete.
# 60% complete.
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\scipy\optimize\minpack.py:163: RuntimeWarning: The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
#   warnings.warn(msg, RuntimeWarning)
# 70% complete.
# 80% complete.
# 90% complete.

# %%
plotting.plt_inhib_cis(M2c_inhib_simsa, time, ci="sd") #t>5 with ramp
# Out:
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\seaborn\timeseries.py:183: UserWarning: The `tsplot` function is deprecated and will be removed in a future release. Please update your code to use the new `lineplot` function.
#   warnings.warn(msg, UserWarning)

# %%
M2c_inhib_simsaa = plotting.inhibdata_to_list(M2c_fxns, thetas_e4_sort, params_constants, initials, time, 2, sig=450000, run_type=['ramp'], ss = True)
# Out:
# 0% complete.
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\scipy\optimize\minpack.py:163: RuntimeWarning: The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
#   warnings.warn(msg, RuntimeWarning)
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\scipy\optimize\minpack.py:163: RuntimeWarning: The iteration is not making good progress, as measured by the
#   improvement from the last five Jacobian evaluations.
#   warnings.warn(msg, RuntimeWarning)
# 10% complete.
# 20% complete.
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\scipy\optimize\minpack.py:163: RuntimeWarning: The number of calls to function has reached maxfev = 1000.
#   warnings.warn(msg, RuntimeWarning)
# 30% complete.
# 40% complete.
# 50% complete.
# 60% complete.
# 70% complete.
# 80% complete.
# 90% complete.

# %%
plotting.plt_inhib_cis(M2c_inhib_simsaa, time, ci="sd") #t>5 with ramp
# Out:
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\seaborn\timeseries.py:183: UserWarning: The `tsplot` function is deprecated and will be removed in a future release. Please update your code to use the new `lineplot` function.
#   warnings.warn(msg, UserWarning)

# %%
plotting.plt_inhib_cis(M2c_inhib_sims, time, ci="sd") #t>30 with ramp
# Out:
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\seaborn\timeseries.py:183: UserWarning: The `tsplot` function is deprecated and will be removed in a future release. Please update your code to use the new `lineplot` function.
#   warnings.warn(msg, UserWarning)

# %%
plotting.plt_inhib_cis(M2c_inhib_sims, time, ci="sd") #t>1
# Out:
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\seaborn\timeseries.py:183: UserWarning: The `tsplot` function is deprecated and will be removed in a future release. Please update your code to use the new `lineplot` function.
#   warnings.warn(msg, UserWarning)

# %%
plotting.plt_inhib_cis(M2c_inhib_sims, time, ci="sd") #t<20
# Out:
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\seaborn\timeseries.py:183: UserWarning: The `tsplot` function is deprecated and will be removed in a future release. Please update your code to use the new `lineplot` function.
#   warnings.warn(msg, UserWarning)
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\numpy\core\_methods.py:116: RuntimeWarning: overflow encountered in multiply
#   x = um.multiply(x, x, out=x)
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\numpy\core\_methods.py:117: RuntimeWarning: overflow encountered in reduce
#   ret = umr_sum(x, axis, dtype, out, keepdims)

# %%
plotting.plt_inhib_cis(M2c_inhib_sims, time, ci="sd") #t>20
# Out:
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\seaborn\timeseries.py:183: UserWarning: The `tsplot` function is deprecated and will be removed in a future release. Please update your code to use the new `lineplot` function.
#   warnings.warn(msg, UserWarning)

# %%
plotting.plt_inhib_cis(M2c_inhib_sims, time, ci="sd") #t>5
# Out:
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\seaborn\timeseries.py:183: UserWarning: The `tsplot` function is deprecated and will be removed in a future release. Please update your code to use the new `lineplot` function.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# ### Investigating modality

# %% [markdown]
# PCA to see if modality can be explained by theta variance. Also, see if better scores are clustering together.

# %%
from sklearn.preprocessing import StandardScaler

df_top_thetas_e2_log = df_top_thetas_e2.apply(np.log10)

df_top_thetas_e2_log['mses'] = mses_e2_sort

x = df_top_thetas_e2_log.loc[:, labelnames].values
y = df_top_thetas_e2_log.loc[:,['mses']].values
x = StandardScaler().fit_transform(x)

from sklearn.decomposition import PCA
pca = PCA(n_components=3)
principalComponents = pca.fit_transform(x)
principalDf = pd.DataFrame(data = principalComponents
             , columns = ['pc1', 'pc2', 'pc3'])

finalDf = pd.concat([principalDf, df_top_thetas_e2_log[['mses']]], axis = 1)

fig = plt.figure(figsize = (8,8))
ax = fig.add_subplot(1,1,1) 
ax.set_xlabel('Principal Component 1', fontsize = 15)
ax.set_ylabel('Principal Component 2', fontsize = 15)
ax.set_title('2 component PCA', fontsize = 20)

sns.scatterplot(x='pc1', y='pc2', hue='mses', size='mses',sizes=(20, 200), data=finalDf[finalDf['mses']<2400], palette="rocket")

ax.grid()

# %%
df_top_params_e2 = pd.DataFrame(thetas_e2)
df_top_params_e2.columns = labelnames
sns.distplot(df_top_params_e2[labelnames[7]])

# %%
sns.distplot(np.log10(df_top_params_e2[labelnames[7]]))

# %%
plotting.plt_param_behaviors(M2b_fxns, thetas_e2, 20, params_constants, initials,  doses, time, 2, mapk_wt_data, mapk_t100a_data, mapk_time,ss=True)

# %%
plotting.plt_param_behaviors(M2b_fxns, thetas_e2, 20, params_constants, initials,  [150000, 550000], time, 1, map2k_wt_data, map2k_t100a_data, mapk_time,ss=True)

# %% [markdown]
# ## Schedule 3

# %%
probs = scaled_prob_mses(mses_e2_sort, top=.99, bot=.01) 

print(probs[:5]) 
print(probs[-5:])
# Out:
# [0.04888099452174417, 0.04669496498687672, 0.024810986035939588, 0.014745285235907818, 0.01253436732132729]
# [0.0004952967146569175, 0.0004947642857514056, 0.0004946074041883233, 0.0004938607537933468, 0.0004937474194115574]

# %%
mses_e3, thetas_e3, count_e3 = run_schedule(thetas_e2_sort, probs, e3, num_theta_primes=1000)
mses_e3_sort, thetas_e3_sort = sort_mses_thetas(mses_e3, thetas_e3)
# Out:
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\scipy\optimize\minpack.py:163: RuntimeWarning: The iteration is not making good progress, as measured by the
#   improvement from the last five Jacobian evaluations.
#   warnings.warn(msg, RuntimeWarning)
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\scipy\optimize\minpack.py:163: RuntimeWarning: The number of calls to function has reached maxfev = 1000.
#   warnings.warn(msg, RuntimeWarning)
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\scipy\optimize\minpack.py:163: RuntimeWarning: The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
#   warnings.warn(msg, RuntimeWarning)
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\scipy\integrate\odepack.py:236: ODEintWarning: Repeated convergence failures (perhaps bad Jacobian or tolerances). Run with full_output = 1 to get quantitative information.
#   warnings.warn(warning_msg, ODEintWarning)
# ../../python_modules\model.py:361: RuntimeWarning: overflow encountered in double_scalars
#   dgly = s7*MAPK - d8*gly
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\scipy\integrate\odepack.py:236: ODEintWarning: Illegal input detected (internal error). Run with full_output = 1 to get quantitative information.
#   warnings.warn(warning_msg, ODEintWarning)
# ../../python_modules\model_supp.py:205: RuntimeWarning: overflow encountered in square
#   mses[18] = ((data - mapk[closest_idxs_ramp_time])**2).mean()
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\scipy\integrate\odepack.py:236: ODEintWarning: Excess work done on this call (perhaps wrong Dfun type). Run with full_output = 1 to get quantitative information.
#   warnings.warn(warning_msg, ODEintWarning)
# ../../python_modules\model.py:359: RuntimeWarning: invalid value encountered in double_scalars
#   dMAP2K = (((k3)*MAP3K*MAP2K_I)/(K_3+MAP2K_I)) - (k4*MAP2K/(K_4+MAP2K))
# ../../python_modules\model.py:360: RuntimeWarning: invalid value encountered in double_scalars
#   dMAPK = (((k5*MAP2K + MAPK*alpha))*MAPK_I)/(K_5+MAPK_I) - (k6*MAPK)/(K_6+MAPK)  #bug
# ../../python_modules\model.py:361: RuntimeWarning: invalid value encountered in double_scalars
#   dgly = s7*MAPK - d8*gly
# 10% complete.
# 20% complete.
# 30% complete.
# 40% complete.
# 50% complete.
# ../../python_modules\model_supp.py:182: RuntimeWarning: overflow encountered in square
#   mses[i] = ((data - mapk[closest_idxs_t100a_long])**2).mean()
# 60% complete.
# 70% complete.
# ../../python_modules\model_supp.py:162: RuntimeWarning: overflow encountered in square
#   mses[i] = ((data - mapk[closest_idxs_mapk])**2).mean()
# 80% complete.
# 90% complete.
# 100% complete.

# %%
df_top_thetas_e3 = pd.DataFrame(thetas_e3_sort)
df_top_thetas_e3.columns = labelnames

df_top_thetas_e3.to_csv('M2c_kb_thetas_e3.csv')

# %%
num_plt = 250
df_plt = pd.DataFrame(thetas_e3_sort[:num_plt])
df_plt.columns = labelnames
df_plt_log = df_plt.apply(np.log10)
df_plt_log_M = df_plt_log.melt(var_name='param', value_name='vals')

plotting.plt_param_ranges(labelnames, 'M2a', dims, df_plt_log_M, single_theta=df_plt_log, num=0)

# %%
sns.distplot(np.log10(df_top_thetas_e3[labelnames[6]]))

# %%
plotting.plt_param_behaviors(M2c_fxns, thetas_e3_sort, 20, params_constants, initials,  doses, time, 2, mapk_wt_data, mapk_t100a_data, mapk_time,ss=True)

# %%
plotting.plt_param_behaviors(M2c_fxns, thetas_e3_sort, 10, params_constants, initials,  [150000, 550000], time, 1, map2k_wt_data, map2k_t100a_data, mapk_time,ss=True)

# %%
sims_M2c_kb_e3 = plotting.simdata_to_list(M2c_fxns, thetas_e3_sort, params_constants, initials, time, 2, ss = True)
# Out:
# 0% complete.
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\scipy\optimize\minpack.py:163: RuntimeWarning: The iteration is not making good progress, as measured by the
#   improvement from the last five Jacobian evaluations.
#   warnings.warn(msg, RuntimeWarning)
# 10% complete.
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\scipy\optimize\minpack.py:163: RuntimeWarning: The number of calls to function has reached maxfev = 1000.
#   warnings.warn(msg, RuntimeWarning)
# 20% complete.
# 30% complete.
# 40% complete.
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\scipy\optimize\minpack.py:163: RuntimeWarning: The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
#   warnings.warn(msg, RuntimeWarning)
# 50% complete.
# 60% complete.
# 70% complete.
# 80% complete.
# 90% complete.

# %%
plotting.plt_ramp_cis(sims_M2c_kb_e3, time, hog1_ramp_data=hog1_ramp_data, mapk_ramp_time=mapk_ramp_time, ci='sd')
# Out:
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\seaborn\timeseries.py:183: UserWarning: The `tsplot` function is deprecated and will be removed in a future release. Please update your code to use the new `lineplot` function.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# ## Schedule 4

# %%
probs = scaled_prob_mses(mses_e3_sort, top=.99, bot=.01) 

print(probs[:5]) 
print(probs[-5:])
# Out:
# [0.052822451288754665, 0.011774704465982845, 0.00830372919118955, 0.007971809883605664, 0.006451689858425836]
# [0.0005341578410669877, 0.0005341157928511535, 0.0005340476825192569, 0.0005336096879767861, 0.0005335601140278249]

# %%
mses_e4_M2b_kb, thetas_e4_M2b_kb, count_e4_M2b_kb = run_schedule(thetas_e3_sort, probs, e4, num_theta_primes=1000)
mses_e4_sort_M2b_kb, thetas_e4_sort_M2b_kb = sort_mses_thetas(mses_e4_M2b_kb, thetas_e4_M2b_kb)
# Out:
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\scipy\optimize\minpack.py:163: RuntimeWarning: The iteration is not making good progress, as measured by the
#   improvement from the last five Jacobian evaluations.
#   warnings.warn(msg, RuntimeWarning)
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\scipy\optimize\minpack.py:163: RuntimeWarning: The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
#   warnings.warn(msg, RuntimeWarning)
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\scipy\optimize\minpack.py:163: RuntimeWarning: The number of calls to function has reached maxfev = 1000.
#   warnings.warn(msg, RuntimeWarning)
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\scipy\integrate\odepack.py:236: ODEintWarning: Repeated convergence failures (perhaps bad Jacobian or tolerances). Run with full_output = 1 to get quantitative information.
#   warnings.warn(warning_msg, ODEintWarning)
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\scipy\integrate\odepack.py:236: ODEintWarning: Excess work done on this call (perhaps wrong Dfun type). Run with full_output = 1 to get quantitative information.
#   warnings.warn(warning_msg, ODEintWarning)
# ../../python_modules\model.py:356: RuntimeWarning: overflow encountered in double_scalars
#   dMAPK = (((k5*MAP2K + MAPK*alpha))*MAPK_I)/(K_5+MAPK_I) - (k6*MAPK)/(K_6+MAPK)  #bug
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\scipy\integrate\odepack.py:236: ODEintWarning: Illegal input detected (internal error). Run with full_output = 1 to get quantitative information.
#   warnings.warn(warning_msg, ODEintWarning)
# 10% complete.
# ../../python_modules\model.py:356: RuntimeWarning: invalid value encountered in double_scalars
#   dMAPK = (((k5*MAP2K + MAPK*alpha))*MAPK_I)/(K_5+MAPK_I) - (k6*MAPK)/(K_6+MAPK)  #bug
# ../../python_modules\model.py:354: RuntimeWarning: invalid value encountered in double_scalars
#   dMAP3K = (((sig*k1 + kb)/(1+gly/beta_3))*MAP3K_I)/(K_1+MAP3K_I) - (k2*MAP3K/(K_2+MAP3K))
# ../../python_modules\model.py:355: RuntimeWarning: invalid value encountered in double_scalars
#   dMAP2K = (((k3)*MAP3K*MAP2K_I)/(K_3+MAP2K_I)) - (k4*MAP2K/(K_4+MAP2K))
# 20% complete.
# 30% complete.
# ../../python_modules\model_supp.py:163: RuntimeWarning: overflow encountered in square
#   mses[i] = ((data - mapk[closest_idxs_mapk])**2).mean()
# ../../python_modules\model_supp.py:206: RuntimeWarning: overflow encountered in square
#   mses[18] = ((data - mapk[closest_idxs_ramp_time])**2).mean()
# 40% complete.
# 50% complete.
# 60% complete.
# 70% complete.
# 80% complete.
# ../../python_modules\model.py:354: RuntimeWarning: divide by zero encountered in double_scalars
#   dMAP3K = (((sig*k1 + kb)/(1+gly/beta_3))*MAP3K_I)/(K_1+MAP3K_I) - (k2*MAP3K/(K_2+MAP3K))
# 90% complete.
# 100% complete.

# %%
df_top_thetas_e4_m2b_kb = pd.DataFrame(thetas_e4_sort_M2b_kb)
df_top_thetas_e4_m2b_kb.columns = labelnames
df_top_thetas_e4_m2b_kb.to_csv('M2c_kb_thetas_e4.csv')

# %%
num_plt = 250
df_plt = pd.DataFrame(df_top_thetas_e4_m2b_kb[:num_plt])
df_plt.columns = labelnames
df_plt_log = df_plt.apply(np.log10)
df_plt_log_M = df_plt_log.melt(var_name='param', value_name='vals')

plotting.plt_param_ranges(labelnames, 'M2a', dims, df_plt_log_M, single_theta=df_plt_log, num=0)

# %%
sns.distplot(np.log10(df_top_thetas_e4_m2b_kb[labelnames[6]]))

# %%
plotting.plt_param_behaviors(M2c_fxns, thetas_e4_sort_M2b_kb, 10, params_constants, initials,  doses, time, 2, mapk_wt_data, mapk_t100a_data, mapk_time,ptp23D=False, ss=True)

# %%
plotting.plt_param_behaviors(M2c_fxns, thetas_e4_sort_M2b_kb, 20, params_constants, initials,  [150000, 550000], time, 1, map2k_wt_data, map2k_t100a_data, mapk_time,ss=True)

# %% [markdown]
# ## Figure 3

# %%
folder_base = 'C:/Users/sksuzuki/Documents/Research/figures/paper1/fig3/'

# %%
plotting.plt_param_cis(M2c_fxns, thetas_e4_sort_M2b_kb, params_constants, initials,  [150000,550000], time, 1,
                        exp_data=map2k_wt_data, exp_time=mapk_time, ss=True, t100a=False, ptpD=False, ci='sd',
                        save_fig=folder_base+'11')
# Out:
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\scipy\optimize\minpack.py:163: RuntimeWarning: The iteration is not making good progress, as measured by the
#   improvement from the last five Jacobian evaluations.
#   warnings.warn(msg, RuntimeWarning)
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\scipy\optimize\minpack.py:163: RuntimeWarning: The number of calls to function has reached maxfev = 1000.
#   warnings.warn(msg, RuntimeWarning)
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\scipy\optimize\minpack.py:163: RuntimeWarning: The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
#   warnings.warn(msg, RuntimeWarning)
# Dose: 150000 complete.
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\seaborn\timeseries.py:183: UserWarning: The `tsplot` function is deprecated and will be removed in a future release. Please update your code to use the new `lineplot` function.
#   warnings.warn(msg, UserWarning)
# Dose: 550000 complete.
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\seaborn\timeseries.py:183: UserWarning: The `tsplot` function is deprecated and will be removed in a future release. Please update your code to use the new `lineplot` function.
#   warnings.warn(msg, UserWarning)

# %%
plotting.plt_param_cis(M2c_fxns, thetas_e4_sort_M2b_kb, params_constants, initials,  [150000,550000], time, 1,
                        exp_data=map2k_t100a_data, exp_time=mapk_time, ss=True, t100a=True, ptpD=False, ci='sd',
                        save_fig=folder_base+'12')
# Out:
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\scipy\optimize\minpack.py:163: RuntimeWarning: The iteration is not making good progress, as measured by the
#   improvement from the last five Jacobian evaluations.
#   warnings.warn(msg, RuntimeWarning)
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\scipy\optimize\minpack.py:163: RuntimeWarning: The number of calls to function has reached maxfev = 1000.
#   warnings.warn(msg, RuntimeWarning)
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\scipy\optimize\minpack.py:163: RuntimeWarning: The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
#   warnings.warn(msg, RuntimeWarning)
# Dose: 150000 complete.
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\seaborn\timeseries.py:183: UserWarning: The `tsplot` function is deprecated and will be removed in a future release. Please update your code to use the new `lineplot` function.
#   warnings.warn(msg, UserWarning)
# Dose: 550000 complete.
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\seaborn\timeseries.py:183: UserWarning: The `tsplot` function is deprecated and will be removed in a future release. Please update your code to use the new `lineplot` function.
#   warnings.warn(msg, UserWarning)

# %%
plotting.plt_param_cis(M2c_fxns, thetas_e4_sort_M2b_kb, params_constants, initials,  doses, time, 2,
                        exp_data=mapk_wt_data, exp_time=mapk_time, ss=True, t100a=False, ptpD=False, ci='sd',
                        save_fig=folder_base+'21')
# Out:
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\scipy\optimize\minpack.py:163: RuntimeWarning: The iteration is not making good progress, as measured by the
#   improvement from the last five Jacobian evaluations.
#   warnings.warn(msg, RuntimeWarning)
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\scipy\optimize\minpack.py:163: RuntimeWarning: The number of calls to function has reached maxfev = 1000.
#   warnings.warn(msg, RuntimeWarning)
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\scipy\optimize\minpack.py:163: RuntimeWarning: The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
#   warnings.warn(msg, RuntimeWarning)
# Dose: 0 complete.
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\seaborn\timeseries.py:183: UserWarning: The `tsplot` function is deprecated and will be removed in a future release. Please update your code to use the new `lineplot` function.
#   warnings.warn(msg, UserWarning)
# Dose: 50000 complete.
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\seaborn\timeseries.py:183: UserWarning: The `tsplot` function is deprecated and will be removed in a future release. Please update your code to use the new `lineplot` function.
#   warnings.warn(msg, UserWarning)
# Dose: 150000 complete.
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\seaborn\timeseries.py:183: UserWarning: The `tsplot` function is deprecated and will be removed in a future release. Please update your code to use the new `lineplot` function.
#   warnings.warn(msg, UserWarning)
# Dose: 250000 complete.
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\seaborn\timeseries.py:183: UserWarning: The `tsplot` function is deprecated and will be removed in a future release. Please update your code to use the new `lineplot` function.
#   warnings.warn(msg, UserWarning)
# Dose: 350000 complete.
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\seaborn\timeseries.py:183: UserWarning: The `tsplot` function is deprecated and will be removed in a future release. Please update your code to use the new `lineplot` function.
#   warnings.warn(msg, UserWarning)
# Dose: 450000 complete.
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\seaborn\timeseries.py:183: UserWarning: The `tsplot` function is deprecated and will be removed in a future release. Please update your code to use the new `lineplot` function.
#   warnings.warn(msg, UserWarning)
# Dose: 550000 complete.
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\seaborn\timeseries.py:183: UserWarning: The `tsplot` function is deprecated and will be removed in a future release. Please update your code to use the new `lineplot` function.
#   warnings.warn(msg, UserWarning)

# %%
plotting.plt_param_cis(M2c_fxns, thetas_e4_sort_M2b_kb, params_constants, initials,  doses, time, 2,
                        exp_data=mapk_t100a_data, exp_time=mapk_time, ss=True, t100a=True, ptpD=False, ci='sd',
                        save_fig=folder_base+'22')
# Out:
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\scipy\optimize\minpack.py:163: RuntimeWarning: The iteration is not making good progress, as measured by the
#   improvement from the last five Jacobian evaluations.
#   warnings.warn(msg, RuntimeWarning)
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\scipy\optimize\minpack.py:163: RuntimeWarning: The number of calls to function has reached maxfev = 1000.
#   warnings.warn(msg, RuntimeWarning)
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\scipy\optimize\minpack.py:163: RuntimeWarning: The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
#   warnings.warn(msg, RuntimeWarning)
# Dose: 0 complete.
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\seaborn\timeseries.py:183: UserWarning: The `tsplot` function is deprecated and will be removed in a future release. Please update your code to use the new `lineplot` function.
#   warnings.warn(msg, UserWarning)
# Dose: 50000 complete.
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\seaborn\timeseries.py:183: UserWarning: The `tsplot` function is deprecated and will be removed in a future release. Please update your code to use the new `lineplot` function.
#   warnings.warn(msg, UserWarning)
# Dose: 150000 complete.
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\seaborn\timeseries.py:183: UserWarning: The `tsplot` function is deprecated and will be removed in a future release. Please update your code to use the new `lineplot` function.
#   warnings.warn(msg, UserWarning)
# Dose: 250000 complete.
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\seaborn\timeseries.py:183: UserWarning: The `tsplot` function is deprecated and will be removed in a future release. Please update your code to use the new `lineplot` function.
#   warnings.warn(msg, UserWarning)
# Dose: 350000 complete.
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\seaborn\timeseries.py:183: UserWarning: The `tsplot` function is deprecated and will be removed in a future release. Please update your code to use the new `lineplot` function.
#   warnings.warn(msg, UserWarning)
# Dose: 450000 complete.
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\seaborn\timeseries.py:183: UserWarning: The `tsplot` function is deprecated and will be removed in a future release. Please update your code to use the new `lineplot` function.
#   warnings.warn(msg, UserWarning)
# Dose: 550000 complete.
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\seaborn\timeseries.py:183: UserWarning: The `tsplot` function is deprecated and will be removed in a future release. Please update your code to use the new `lineplot` function.
#   warnings.warn(msg, UserWarning)

# %%
mapk_time_t100a_long = [0, 2, 5, 10, 15, 20, 25, 30, 60, 90, 120, 150, 180, 240, 300]

plotting.plt_t100a_long(M2c_fxns, thetas_e4_sort_M2b_kb, 10, params_constants, initials, mapk_data_t100a_long[0], mapk_time_t100a_long)

# %%
time_long = np.linspace(0,dt*2001,steps)

# %%
plotting.plt_param_cis(M2c_fxns, thetas_e4_sort_M2b_kb[:707], params_constants, initials,  [350000], time_long, 3,
                        exp_data=None, exp_time=None, ss=True, t100a=False, ptpD=False, ci='sd',
                        save_fig=folder_base+'31')
# Out:
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\scipy\optimize\minpack.py:163: RuntimeWarning: The iteration is not making good progress, as measured by the
#   improvement from the last five Jacobian evaluations.
#   warnings.warn(msg, RuntimeWarning)
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\scipy\optimize\minpack.py:163: RuntimeWarning: The number of calls to function has reached maxfev = 1000.
#   warnings.warn(msg, RuntimeWarning)
# Dose: 350000 complete.
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\seaborn\timeseries.py:183: UserWarning: The `tsplot` function is deprecated and will be removed in a future release. Please update your code to use the new `lineplot` function.
#   warnings.warn(msg, UserWarning)

# %%
plotting.plt_param_cis(M2c_fxns, np.concatenate([thetas_e4_sort_M2b_kb[:707],thetas_e4_sort_M2b_kb[708:800]]), params_constants, initials,  [350000], time, 3,
                        exp_data=None, exp_time=None, ss=True, t100a=False, ptpD=False, ci='sd',
                        save_fig=folder_base+'31')
# Out:
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\scipy\optimize\minpack.py:163: RuntimeWarning: The iteration is not making good progress, as measured by the
#   improvement from the last five Jacobian evaluations.
#   warnings.warn(msg, RuntimeWarning)
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\scipy\optimize\minpack.py:163: RuntimeWarning: The number of calls to function has reached maxfev = 1000.
#   warnings.warn(msg, RuntimeWarning)
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\scipy\optimize\minpack.py:163: RuntimeWarning: The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
#   warnings.warn(msg, RuntimeWarning)
# Dose: 350000 complete.
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\seaborn\timeseries.py:183: UserWarning: The `tsplot` function is deprecated and will be removed in a future release. Please update your code to use the new `lineplot` function.
#   warnings.warn(msg, UserWarning)

# %%
plotting.plt_param_behaviors(M2c_fxns, thetas_e4_sort_M2b_kb[708:850], 20, params_constants, initials,  [350000], time, 3, mapk_wt_data=None, mapk_t100a_data=None, mapk_time=mapk_time,ptp23D=False, ss=True)
# Out:
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\scipy\optimize\minpack.py:163: RuntimeWarning: The iteration is not making good progress, as measured by the
#   improvement from the last five Jacobian evaluations.
#   warnings.warn(msg, RuntimeWarning)

# %%
plotting.plt_param_cis(M2c_fxns, thetas_e4_sort_M2b_kb, params_constants, initials,  [0], time, 2,
                        exp_data=mapk_data_t100a_long, exp_time=mapk_time_t100a_long, ss=True, t100a=True, ptpD=False, ci='sd',
                        save_fig=folder_base+'32')
# Out:
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\scipy\optimize\minpack.py:163: RuntimeWarning: The iteration is not making good progress, as measured by the
#   improvement from the last five Jacobian evaluations.
#   warnings.warn(msg, RuntimeWarning)
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\scipy\optimize\minpack.py:163: RuntimeWarning: The number of calls to function has reached maxfev = 1000.
#   warnings.warn(msg, RuntimeWarning)
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\scipy\optimize\minpack.py:163: RuntimeWarning: The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
#   warnings.warn(msg, RuntimeWarning)
# Dose: 0 complete.
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\seaborn\timeseries.py:183: UserWarning: The `tsplot` function is deprecated and will be removed in a future release. Please update your code to use the new `lineplot` function.
#   warnings.warn(msg, UserWarning)

# %%
sims_M2c_kb_e4 = plotting.simdata_to_list(M2c_fxns, thetas_e4_sort_M2b_kb, params_constants, initials, time, 2, ss = True)

# %%
plotting.plt_ramp_cis(sims_M2c_kb_e4, time, hog1_ramp_data=hog1_ramp_data, mapk_ramp_time=mapk_ramp_time)
# Out:
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\seaborn\timeseries.py:183: UserWarning: The `tsplot` function is deprecated and will be removed in a future release. Please update your code to use the new `lineplot` function.
#   warnings.warn(msg, UserWarning)

# %%
plotting.plt_ramp_cis(sims_M2c_kb_e4, time, hog1_ramp_data=hog1_ramp_data, mapk_ramp_time=mapk_ramp_time, ci='sd', save_fig='M2c_ramp.pdf')

# %%
pbs2 = plotting.simdata_to_list(M2c_fxns, thetas_e4_sort_M2b_kb, params_constants, initials, time, 1, ss = True)
# Out:
# 0% complete.
# 10% complete.
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\scipy\optimize\minpack.py:163: RuntimeWarning: The iteration is not making good progress, as measured by the
#   improvement from the last five Jacobian evaluations.
#   warnings.warn(msg, RuntimeWarning)
# 20% complete.
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\scipy\optimize\minpack.py:163: RuntimeWarning: The number of calls to function has reached maxfev = 1000.
#   warnings.warn(msg, RuntimeWarning)
# 30% complete.
# 40% complete.
# 50% complete.
# 60% complete.
# 70% complete.
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\scipy\optimize\minpack.py:163: RuntimeWarning: The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
#   warnings.warn(msg, RuntimeWarning)
# 80% complete.
# 90% complete.

# %%
plotting.plt_ramp_cis(pbs2, time, hog1_ramp_data=None, mapk_ramp_time=None, ci='sd')

# %% [markdown]
# # Compare my way and the ABC SMC way

# %%
def draw_theta2():
    return 10**(-4+(4-(-4))*np.random.random(17))#np.random.uniform(.0001,1000,17)
    
def draw_thetas2(thetas, weights):
    return 

def step_theta(theta):
    log_theta = np.log10(theta) 
    theta_prime = np.concatenate([10**(np.random.uniform(x-.1,x+.1,1)) for x in log_theta], axis=0)
    return theta_prime

def run_schedule_1(ei, num_theta_primes):
    thetas_ei = []
    mses_ei = []
    c = collections.Counter({'Pass': 0, 'Fail': 0}) 
    while len(thetas_ei) < num_theta_primes:
        theta_prime = draw_theta2()
#         theta = draw_thetas(prior_thetas, probs)
#         theta_prime = step_theta(theta)
        mse = calc_mse(M2c_fxns, theta_prime, exp_data, exp_time, params_constants, initials, ptpD=False) ##AMY error fxn
        if mse < ei:
            c['Pass'] += 1
            thetas_ei.append(theta_prime)
            mses_ei.append(mse)
            if len(mses_ei) % int(num_theta_primes*.1) == 0:
                print(str(int(len(mses_ei)/num_theta_primes*100)) + "% complete.") 
        else:
            c['Fail'] += 1
    return np.asarray(mses_ei), np.asarray(thetas_ei), c

def run_schedule_i(ei, num_theta_primes):
    thetas_ei = []
    mses_ei = []
    c = collections.Counter({'Pass': 0, 'Fail': 0}) 
    while len(thetas_ei) < num_theta_primes:
        theta_prime = draw_theta2()
#         theta = draw_thetas(prior_thetas, probs)
#         theta_prime = step_theta(theta)
        mse = calc_mse(M2c_fxns, theta_prime, exp_data, exp_time, params_constants, initials, ptpD=False) ##AMY error fxn
        if mse < ei:
            c['Pass'] += 1
            thetas_ei.append(theta_prime)
            mses_ei.append(mse)
            if len(mses_ei) % int(num_theta_primes*.1) == 0:
                print(str(int(len(mses_ei)/num_theta_primes*100)) + "% complete.") 
        else:
            c['Fail'] += 1
    return np.asarray(mses_ei), np.asarray(thetas_ei), c

# %%
ABC_SMC_mses1, ABC_SMC_thetas1, ABC_SMC_c1 = run_schedule_1(e1, 1000)
# Out:
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\scipy\optimize\minpack.py:163: RuntimeWarning: The iteration is not making good progress, as measured by the
#   improvement from the last five Jacobian evaluations.
#   warnings.warn(msg, RuntimeWarning)
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\scipy\optimize\minpack.py:163: RuntimeWarning: The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
#   warnings.warn(msg, RuntimeWarning)
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\scipy\integrate\odepack.py:236: ODEintWarning: Excess work done on this call (perhaps wrong Dfun type). Run with full_output = 1 to get quantitative information.
#   warnings.warn(warning_msg, ODEintWarning)
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\scipy\integrate\odepack.py:236: ODEintWarning: Repeated convergence failures (perhaps bad Jacobian or tolerances). Run with full_output = 1 to get quantitative information.
#   warnings.warn(warning_msg, ODEintWarning)
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\scipy\optimize\minpack.py:163: RuntimeWarning: The number of calls to function has reached maxfev = 1000.
#   warnings.warn(msg, RuntimeWarning)
# ../../python_modules\model.py:371: RuntimeWarning: overflow encountered in double_scalars
#   sig = get_ramp_signal(t, run_type[1])
# ../../python_modules\model.py:371: RuntimeWarning: invalid value encountered in double_scalars
#   sig = get_ramp_signal(t, run_type[1])
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\scipy\integrate\odepack.py:236: ODEintWarning: Illegal input detected (internal error). Run with full_output = 1 to get quantitative information.
#   warnings.warn(warning_msg, ODEintWarning)
# ../../python_modules\model_supp.py:162: RuntimeWarning: overflow encountered in square
#   mses[i] = ((data - mapk[closest_idxs_mapk])**2).mean()
# ../../python_modules\model_supp.py:182: RuntimeWarning: overflow encountered in square
#   mses[i] = ((data - mapk[closest_idxs_t100a_long])**2).mean()
# ../../python_modules\model_supp.py:187: RuntimeWarning: overflow encountered in square
#   mses[i] = ((data - mapk[closest_idxs_mapk])**2).mean()
# ../../python_modules\model_supp.py:205: RuntimeWarning: overflow encountered in square
#   mses[18] = ((data - mapk[closest_idxs_ramp_time])**2).mean()
# ../../python_modules\model.py:369: RuntimeWarning: divide by zero encountered in double_scalars
#   sig = signal_ramp_special(t)
# ../../python_modules\model.py:369: RuntimeWarning: invalid value encountered in double_scalars
#   sig = signal_ramp_special(t)
# ../../python_modules\model.py:370: RuntimeWarning: invalid value encountered in double_scalars
#   elif run_type[0] == 'rand':
# ../../python_modules\model.py:372: RuntimeWarning: invalid value encountered in double_scalars
#   elif run_type[0] == 'man':
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\scipy\integrate\odepack.py:236: ODEintWarning: Repeated error test failures (internal error). Run with full_output = 1 to get quantitative information.
#   warnings.warn(warning_msg, ODEintWarning)
# ../../python_modules\model.py:371: RuntimeWarning: divide by zero encountered in double_scalars
#   sig = get_ramp_signal(t, run_type[1])
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\scipy\integrate\odepack.py:236: ODEintWarning: Excess accuracy requested (tolerances too small). Run with full_output = 1 to get quantitative information.
#   warnings.warn(warning_msg, ODEintWarning)
# -----------------------------------------------------
# KeyboardInterrupt   Traceback (most recent call last)
# <ipython-input-312-6b5c8ebc72fd> in <module>()
# ----> 1 ABC_SMC_mses1, ABC_SMC_thetas1, ABC_SMC_c1 = run_schedule_1(e1, 1000)
#
# <ipython-input-311-f5d8596aafbe> in run_schedule_1(ei, num_theta_primes)
#      18 #         theta = draw_thetas(prior_thetas, probs)
#      19 #         theta_prime = step_theta(theta)
# ---> 20         mse = calc_mse(M2c_fxns, theta_prime, exp_data, exp_time, params_constants, initials, ptpD=False) ##AMY error fxn
#      21         if mse < ei:
#      22             c['Pass'] += 1
#
# <ipython-input-102-21fa10d9f160> in calc_mse(model_fxns, theta, exp_data, exp_time, params_constants, initials, ptpD)
#      15 def calc_mse(model_fxns, theta, exp_data, exp_time, params_constants, initials, ptpD=False):
#      16     # Takes
# ---> 17     return sum(model_supp.calc_sim_score(model_fxns, theta, exp_data, exp_time, params_constants, initials, ptpD)[:18]) ##AMY (insert your own error function)
#      18
#      19 def def_schedules(sorted_mses):
#
# ~\Documents\GitHub\HOG_encoding_feedbacks\python_modules\model_supp.py in calc_sim_score(model_fxns, params, data, exp_time, total_protein, inits, ptpD)
#     158
#     159     for i, (dose, data) in enumerate(zip(hog1_doses, mapk_wt_data), 0):
# --> 160         odes = model.simulate_wt_experiment(model_fxns.m, wt_ss_inits, total_protein, dose, params, time)#mapk_time)
#     161         mapk = odes[:,2]/total_protein[2]*100
#     162         mses[i] = ((data - mapk[closest_idxs_mapk])**2).mean()
#
# ~\Documents\GitHub\HOG_encoding_feedbacks\python_modules\model.py in simulate_wt_experiment(m, inits, total_protein, sig, learned_params, time, run_type)
#      10
#      11 def simulate_wt_experiment(m, inits, total_protein, sig, learned_params, time, run_type=None):
# ---> 12     odes = odeint(m, inits, time, args=(total_protein, sig, learned_params, run_type))
#      13     return odes
#      14
#
# ~\Anaconda3\lib\site-packages\scipy\integrate\odepack.py in odeint(func, y0, t, args, Dfun, col_deriv, full_output, ml, mu, rtol, atol, tcrit, h0, hmax, hmin, ixpr, mxstep, mxhnil, mxordn, mxords, printmessg, tfirst)
#     231                              full_output, rtol, atol, tcrit, h0, hmax, hmin,
#     232                              ixpr, mxstep, mxhnil, mxordn, mxords,
# --> 233                              int(bool(tfirst)))
#     234     if output[-1] < 0:
#     235         warning_msg = _msgs[output[-1]] + " Run with full_output = 1 to get quantitative information."
#
# ~\Documents\GitHub\HOG_encoding_feedbacks\python_modules\model.py in M2c_kb(initials, t, total_protein, sig, params, run_type)
#     351 def M2c_kb(initials,t,total_protein,sig,params,run_type=None):
#     352     # print(initials)
# --> 353     if run_type:
#     354         if run_type[0] == 'ramp':
#     355             sig = signal_ramp_special(t)
#
# KeyboardInterrupt:

# %% [markdown]
# # inhib

# %%
M2c_inhib_sims = plotting.inhibdata_to_list(M2c_fxns, thetas_e4_sort_M2b_kb, params_constants, initials, time, 2, sig=450000, run_type=['ramp'], ss = True)
# Out:
# 0% complete.
# 10% complete.
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\scipy\optimize\minpack.py:163: RuntimeWarning: The iteration is not making good progress, as measured by the
#   improvement from the last five Jacobian evaluations.
#   warnings.warn(msg, RuntimeWarning)
# 20% complete.
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\scipy\optimize\minpack.py:163: RuntimeWarning: The number of calls to function has reached maxfev = 1000.
#   warnings.warn(msg, RuntimeWarning)
# 30% complete.
# 40% complete.
# 50% complete.
# 60% complete.
# 70% complete.
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\scipy\optimize\minpack.py:163: RuntimeWarning: The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
#   warnings.warn(msg, RuntimeWarning)
# 80% complete.
# 90% complete.

# %%
plotting.plt_inhib_cis(M2c_inhib_sims, time, ci="sd") #t>5 with ramp
# Out:
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\seaborn\timeseries.py:183: UserWarning: The `tsplot` function is deprecated and will be removed in a future release. Please update your code to use the new `lineplot` function.
#   warnings.warn(msg, UserWarning)
